# %%
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
from numpy import poly1d,polyfit  
import matplotlib.pyplot as plt

# %% [markdown]
# ### Agua líquida

# %%
"""
En la siguiente sección del codigo se obtiene un polinomio que ajusta los valores del Cp del "agua" a un 
polinomio de grado 5, esto para evitar el uso de tablas en el programa, las unidades de esta función están 
dadas en (T[=]ºC) y (Cp[=] KJ K^-1 Kg^-1) 
"""

Dataset = pd.read_csv(r'../../Tablas CSV/Thermophysics Propieties-Satured Liquids/Water-Liquid.csv')

# Obtencion del polinomio
Poly = poly1d(polyfit(Dataset['T(k)'],Dataset['Cp'], deg=5), variable='x') 
print(Poly)
display(Poly)

# Evaluacion del polinomio en el rango de nuestra psi
y = Poly(Dataset['T(k)'])

plt.plot(Dataset['T(k)'],Dataset['Cp'],marker=".",label="Experimental Data")
plt.plot(Dataset['T(k)'],y,marker=".",label="Polyfit Data")

plt.title(r'Cp,Water $\frac{KJ}{KKg}$')
plt.legend()
plt.grid()
plt.show()


"""
En la siguiente sección del codigo se obtiene un polinomio que ajusta los valores de la densidad del "Agua"
a un polinomio de grado {}, esto para evitar el uso de tablas en el programa, las unidades de esta función están 
dadas en (T[=]ºC) y (P[=] Kg M^-3) 
"""

Dataset = pd.read_csv(r'../../Tablas CSV/Thermophysics Propieties-Satured Liquids/Water-Liquid.csv')

# Obtencion del polinomio
Poly = poly1d(polyfit(Dataset['T(k)'],Dataset['Density'], deg=3), variable='x') 
print(Poly)
display(Poly)


# Evaluacion del polinomio en el rango de nuestra psi
y = Poly(Dataset['T(k)'])

plt.plot(Dataset['T(k)'],Dataset['Density'],marker=".",label="Experimental Data")
plt.plot(Dataset['T(k)'],y,marker=".",label="Polyfit Data")

plt.title(r'Density,Water $\frac{Kg}{m^3}$')
plt.legend()
plt.grid()
plt.show()



"""
En la siguiente sección del codigo se obtiene un polinomio que ajusta los valores de la densidad del "Aceite de motor
sin usar" a un polinomio de grado {}, esto para evitar el uso de tablas en el programa, las unidades de esta función están 
dadas en (T[=]ºC) y (P[=] Kg M^-3) 
"""

Dataset = pd.read_csv(r'../../Tablas CSV/Thermophysics Propieties-Satured Liquids/Water-Liquid.csv')

# Obtencion del polinomio
Poly = poly1d(polyfit(Dataset['T(k)'],Dataset['Dinamic Viscocity'], deg=4), variable='x') 
print(Poly)
display(Poly)


# Evaluacion del polinomio en el rango de nuestra psi
y = Poly(Dataset['T(k)'])

plt.plot(Dataset['T(k)'],Dataset['Dinamic Viscocity'],marker=".",label="Experimental Data")
plt.plot(Dataset['T(k)'],y,marker=".",label="Polyfit Data")

plt.title(r'Dynamic Viscocity,Water $\frac{Kg}{m.s}$')
plt.legend()
plt.grid()
plt.show()

"""
En la siguiente sección del codigo se obtiene un polinomio que ajusta los valores del número de Pr para "Aceite de motor
sin usar" a un polinomio de grado {}, esto para evitar el uso de tablas en el programa, las unidades de esta función están 
dadas en magnitudes unidimensionales 
"""

Dataset = pd.read_csv(r'../../Tablas CSV/Thermophysics Propieties-Satured Liquids/Water-Liquid.csv')

# Obtencion del polinomio
Poly = poly1d(polyfit(Dataset['T(k)'],Dataset['Pr'], deg=4), variable='x') 
print(Poly)
display(Poly)


# Evaluacion del polinomio en el rango de nuestra psi
y = Poly(Dataset['T(k)'])

plt.plot(Dataset['T(k)'],Dataset['Pr'],marker=".",label="Experimental Data")
plt.plot(Dataset['T(k)'],y,marker=".",label="Polyfit Data")

plt.title(r'Pr,Water')
plt.legend()
plt.grid()
plt.show()
# Out:
#            5             4             3           2
# -4.85e-11 x + 8.162e-08 x - 5.485e-05 x + 0.01841 x - 3.087 x + 211.1
# poly1d([-4.84985762e-11,  8.16152621e-08, -5.48496005e-05,  1.84096211e-02,
#        -3.08685069e+00,  2.11075200e+02])
#            3             2
# 1.492e-08 x - 1.799e-05 x + 0.006495 x + 0.2643
# poly1d([ 1.49227078e-08, -1.79921582e-05,  6.49530932e-03,  2.64335255e-01])
#            4           3         2
# 2.867e-05 x - 0.03938 x + 20.33 x - 4680 x + 4.064e+05
# poly1d([ 2.86650833e-05, -3.93763073e-02,  2.03280503e+01, -4.68030316e+03,
#         4.06389038e+05])
#            4             3          2
# 2.557e-07 x - 0.0003503 x + 0.1803 x - 41.34 x + 3571
# poly1d([ 2.55712532e-07, -3.50292992e-04,  1.80259651e-01, -4.13410432e+01,
#         3.57137220e+03])

# %% [markdown]
# ### Aceite de Motor sin Usar

# %%
"""
En la siguiente sección del codigo se obtiene un polinomio que ajusta los valores del Cp del "agua" a un 
polinomio de grado 5, esto para evitar el uso de tablas en el programa, las unidades de esta función están 
dadas en (T[=]ºC) y (Cp[=] KJ K^-1 Kg^-1) 
"""

Dataset = pd.read_csv(r'../../Tablas CSV/Thermophysics Propieties-Satured Liquids/Unused Motor Oil.csv')

# Obtencion del polinomio
Poly = poly1d(polyfit(Dataset['T(k)'],Dataset['Cp'], deg=1), variable='x') 
print(Poly)
display(Poly)

# Evaluacion del polinomio en el rango de nuestra psi
y = Poly(Dataset['T(k)'])

plt.plot(Dataset['T(k)'],Dataset['Cp'],marker=".",label="Experimental Data")
plt.plot(Dataset['T(k)'],y,marker=".",label="Polyfit Data")

plt.title(r'Cp,Water $\frac{KJ}{KKg}$')
plt.legend()
plt.grid()
plt.show()


"""
En la siguiente sección del codigo se obtiene un polinomio que ajusta los valores de la densidad del "Agua"
a un polinomio de grado {}, esto para evitar el uso de tablas en el programa, las unidades de esta función están 
dadas en (T[=]ºC) y (P[=] Kg M^-3) 
"""

Dataset = pd.read_csv(r'../../Tablas CSV/Thermophysics Propieties-Satured Liquids/Unused Motor Oil.csv')

# Obtencion del polinomio
Poly = poly1d(polyfit(Dataset['T(k)'],Dataset['Density'], deg=1), variable='x') 
print(Poly)
display(Poly)

# Evaluacion del polinomio en el rango de nuestra psi
y = Poly(Dataset['T(k)'])

plt.plot(Dataset['T(k)'],Dataset['Density'],marker=".",label="Experimental Data")
plt.plot(Dataset['T(k)'],y,marker=".",label="Polyfit Data")

plt.title(r'Density,Water $\frac{Kg}{m^3}$')
plt.legend()
plt.grid()
plt.show()



"""
En la siguiente sección del codigo se obtiene un polinomio que ajusta los valores de la densidad del "Aceite de motor
sin usar" a un polinomio de grado {}, esto para evitar el uso de tablas en el programa, las unidades de esta función están 
dadas en (T[=]ºC) y (P[=] Kg M^-3) 
"""

Dataset = pd.read_csv(r'../../Tablas CSV/Thermophysics Propieties-Satured Liquids/Unused Motor Oil.csv')

# Obtencion del polinomio
Poly = poly1d(polyfit(Dataset['T(k)'],Dataset['Dinamic Viscocity'], deg=7), variable='x') 
print(Poly)
display(Poly)

# Evaluacion del polinomio en el rango de nuestra psi
y = Poly(Dataset['T(k)'])

plt.plot(Dataset['T(k)'],Dataset['Dinamic Viscocity'],marker=".",label="Experimental Data")
plt.plot(Dataset['T(k)'],y,marker=".",label="Polyfit Data")

plt.title(r'Dynamic Viscocity,Water $\frac{Kg}{m.s}$')
plt.legend()
plt.grid()
plt.show()

"""
En la siguiente sección del codigo se obtiene un polinomio que ajusta los valores del número de Pr para "Aceite de motor
sin usar" a un polinomio de grado {}, esto para evitar el uso de tablas en el programa, las unidades de esta función están 
dadas en magnitudes unidimensionales 
"""

Dataset = pd.read_csv(r'../../Tablas CSV/Thermophysics Propieties-Satured Liquids/Unused Motor Oil.csv')

# Obtencion del polinomio
Poly = poly1d(polyfit(Dataset['T(k)'],Dataset['Pr'], deg=7), variable='x') 
print(Poly)
display(Poly)

# Evaluacion del polinomio en el rango de nuestra psi
y = Poly(Dataset['T(k)'])

plt.plot(Dataset['T(k)'],Dataset['Pr'],marker=".",label="Experimental Data")
plt.plot(Dataset['T(k)'],y,marker=".",label="Polyfit Data")

plt.title(r'Pr,Water')
plt.legend()
plt.grid()
plt.show()
# Out:
#
# 0.004287 x + 0.6222
# poly1d([0.00428723, 0.62224249])
#
# -0.5921 x + 1061
# poly1d([-5.92123941e-01,  1.06126552e+03])
#             7             6             5           4         3
# -1.201e-11 x + 3.064e-08 x - 3.341e-05 x + 0.02019 x - 7.304 x
#          2
#  + 1582 x - 1.9e+05 x + 9.756e+06
# poly1d([-1.20139335e-11,  3.06384253e-08, -3.34071017e-05,  2.01894730e-02,
#        -7.30421324e+00,  1.58203522e+03, -1.89963325e+05,  9.75619374e+06])
#             7             6            5         4       3
# -1.103e-09 x + 2.829e-06 x - 0.003103 x + 1.887 x - 687 x
#               2
#  + 1.498e+05 x - 1.811e+07 x + 9.37e+08
# poly1d([-1.10326004e-09,  2.82939045e-06, -3.10319059e-03,  1.88691141e+00,
#        -6.87028683e+02,  1.49801108e+05, -1.81131299e+07,  9.37048049e+08])

# %% [markdown]
# ### Funciones

# %%
def Cp(Fluid,T):
    x = T
    if Fluid=='water':
        c = [-4.84985762e-11,  8.16152621e-08, -5.48496005e-05,  1.84096211e-02, -3.08685069e+00,  2.11075200e+02]
        Cp_species = c[0]*x**5 + c[1]*x**4 + c[2]*x**3 + c[3]*T**2 + c[4]*T + c[5]   
    elif Fluid=="unused oil":
        c = [0.00428723, 0.62224249]
        Cp_species = c[0]*T + c[1]    
    return Cp_species


def Density(Fluid,T):
    x = T
    if Fluid=='water':
        c = [ 1.49227078e-08, -1.79921582e-05,  6.49530932e-03,  2.64335255e-01]
        Density_species = c[0]*x**3 + c[1]*T**2 + c[2]*T + c[3]
    elif Fluid=="unused oil":
        c = [-5.92123941e-01,  1.06126552e+03]
        Density_species = c[0]*x + c[1] 
    return Density_species


def Viscocity(Fluid,T):
    x = T
    if Fluid=='water':
        c = [ 2.86650833e-05, -3.93763073e-02,  2.03280503e+01, -4.68030316e+03, 4.06389038e+05]
        Viscocity_species = c[0]*x**4 + c[1]*x**3 + c[2]*T**2 + c[3]*T + c[4]
    elif Fluid=="unused oil":
        c = [-1.20139335e-11,  3.06384253e-08, -3.34071017e-05,  2.01894730e-02, -7.30421324e+00,  1.58203522e+03, -1.89963325e+05,  9.75619374e+06]
        Viscocity_species = c[0]*x**7 + c[1]*x**6 + c[2]*T**5 + c[3]*x**4 + c[4]*x**3 + c[5]*T**2 + c[6]*T + c[7] 
    return Viscocity_species


def Prandtl(Fluid,T):
    x = T
    if Fluid=='water':
        c = [ 2.55712532e-07, -3.50292992e-04,  1.80259651e-01, -4.13410432e+01, 3.57137220e+03]
        Pr_species = c[0]*x**4 + c[1]*x**3 + c[2]*T**2 + c[3]*T + c[4]  
    elif Fluid=="unused oil":
        c = [-1.10326004e-09,  2.82939045e-06, -3.10319059e-03,  1.88691141e+00, -6.87028683e+02,  1.49801108e+05, -1.81131299e+07,  9.37048049e+08]
        Pr_species = c[0]*x**7 + c[1]*x**6 + c[2]*T**5 + c[3]*x**4 + c[4]*x**3 + c[5]*T**2 + c[6]*T + c[7] 
    return Pr_species

# %%
Water = pd.read_csv(r'../../Tablas CSV/Thermophysics Propieties-Satured Liquids/Water-Liquid.csv')
Oil = pd.read_csv(r'../../Tablas CSV/Thermophysics Propieties-Satured Liquids/Unused Motor Oil.csv')

display(Water)
display(Oil)
# Out:
#       T(k)   Density     Cp  Dinamic Viscocity  Cinematic Viscocity   K   \
# 0   273.15  1.000000  4.217               1750                  NaN  569
# 1   275.00  1.000000  4.211               1652                  NaN  574
# 2   280.00  1.000000  4.198               1422                  NaN  582
# 3   285.00  1.000000  4.189               1225                  NaN  590
# 4   290.00  0.999001  4.184               1080                  NaN  598
# 5   295.00  0.998004  4.181                959                  NaN  606
# 6   300.00  0.997009  4.179                855                  NaN  613
# 7   305.00  0.995025  4.178                769                  NaN  620
# 8   310.00  0.993049  4.178                695                  NaN  628
# 9   315.00  0.991080  4.179                631                  NaN  634
# 10  320.00  0.989120  4.180                577                  NaN  640
# 11  325.00  0.987167  4.182                528                  NaN  645
# ...

# %% [markdown]
# ### Comprobación

# %%
print(Cp('water',370))
print(Density('water',370))
print(Viscocity('water',370))
print(Prandtl('water',370))
# Out:
# 4.213853232078463
# 0.9603531640134004
# 288.673029212805
# 1.806060980521579

# %%
print(Cp('unused oil',370))
print(Density('unused oil',370))
print(Viscocity('unused oil',370))
print(Prandtl('unused oil',370))
# Out:
# 2.20851759
# 842.17966183
# 2.8891906943172216
# 391.7017412185669

# %%
T =142.5+273.15
Fluid = 'water'
print(f"Cp: {Cp(Fluid,T)}")
print(f"Density :{Density(Fluid,T)}")
print(f"Viscocity :{Viscocity(Fluid,T)}")
print(f"Pr : {Prandtl(Fluid,T)}")
# Out:
# Cp: 4.1730459436114415
# Density :0.9272925245952381
# Viscocity :980.0089485457283
# Pr : 8.499194825320956
